# %% [markdown]
# # Train Separate Value Network (Colab G4)
#
# Train a small ValueNet (5b×128ch) on survival targets.
# Input: board positions from V7/V8/crisis games.
# Target: min(turns_remaining / 50, 1.0)
#
# **Upload to Drive (`MyDrive/alphatrain/`):**
# 1. `colorlines_selfplay_train.tar.gz` — code
# 2. `value_train.pt` — training data (187 MB)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
DRIVE = '/content/drive/MyDrive/alphatrain'

# !cp {DRIVE}/colorlines_selfplay_train.tar.gz /content/
# !cd /content && tar xzf colorlines_selfplay_train.tar.gz

os.makedirs('/content/alphatrain/data', exist_ok=True)
# !cp {DRIVE}/value_train.pt /content/alphatrain/data/value_train.pt
print(f'Data: {os.path.getsize("/content/alphatrain/data/value_train.pt")/1e6:.0f} MB')

# !pip install -q numpy numba scipy

import torch
print(f'PyTorch: {torch.__version__}')
print(f'CUDA: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    print(f'GPU: {torch.cuda.get_device_name(0)}')

# %%
# %cd /content

# !python -m alphatrain.scripts.train_value \
    --data /content/alphatrain/data/value_train.pt \
    --output {DRIVE}/value_net.pt \
    --epochs 10 --batch-size 8192 --lr 1e-3 \
    --num-blocks 5 --channels 128 \
    --device cuda
